# %%
import os
import pandas as pd
from IPython.display import display

os.chdir('/mnt/c/users/rfont/Documents/Python/database_update')

customers = ["all_buyers.xlsx", 
             "all_buyers_sellers.xlsx", 
             "all_longtermrentals.xlsx",
             "all_sellers.xlsx"]

def standardize_date_columns(df: pd.DataFrame, filename: str) -> pd.DataFrame:
    date_candidates = [col for col in df.columns if any(key in col.lower() for key in ["date", "time", "change", "publish",
    "start", "end", "update"])]
    for col in date_candidates:
        if filename in customers:
            df[col] = pd.to_datetime(df[col], format="%d/%m/%Y", errors="coerce")
        elif filename == "all_properties.xlsx":
            df[col] = pd.to_datetime(df[col], format="%d/%m/%Y %H:%M", errors="coerce")
        elif filename == "all_events.xlsx":
            df[col] = pd.to_datetime(df[col].astype(str), format="%d/%m/%Y - %H:%M", errors="coerce")
        elif filename == "all_leads.xlsx":
            df[col] = pd.to_datetime(df[col].astype(str), format="%d-%m-%Y - %H:%M", errors="coerce")
        else:
            print(f"⚠️ Unknown file: {filename}. Defaulting to date-only format.")
    return df

for f in os.listdir():
    if f.endswith('.xlsx'):
        df = pd.read_excel(f)
        df = standardize_date_columns(df, f)
        date_cols = df.select_dtypes(include=["datetime64[ns]"])
        display(date_cols)
# Out:
#       CreateTime BirthDate
# 0     2025-10-22       NaT
# 1     2025-10-22       NaT
# 2     2025-10-22       NaT
# 3     2025-10-22       NaT
# 4     2025-10-22       NaT
# ...          ...       ...
# 24001 2017-04-26       NaT
# 24002 2017-04-10       NaT
# 24003 2017-03-20       NaT
# 24004 2017-01-11       NaT
# 24005 2017-01-10       NaT
#
# [24006 rows x 2 columns]
#     CreateTime BirthDate
# 0   2016-12-22       NaT
# 1   2017-01-10       NaT
# 2   2017-03-20       NaT
# 3   2017-04-10       NaT
# 4   2017-05-10       NaT
# ..         ...       ...
# 200 2025-04-19       NaT
# 201 2025-05-19       NaT
# 202 2025-08-04       NaT
# 203 2025-08-18       NaT
# 204 2025-10-01       NaT
#
# [205 rows x 2 columns]
#                 EventDate
# 0     2025-10-23 09:41:00
# 1     2025-10-22 21:30:00
# 2     2025-10-22 17:46:00
# 3     2025-10-22 17:41:00
# 4     2025-10-22 17:32:00
# ...                   ...
# 23601 2022-04-22 00:00:00
# 23602 2022-04-22 00:00:00
# 23603 2022-04-22 00:00:00
# 23604 2022-04-22 00:00:00
# 23605 2022-04-22 00:00:00
#
# [23606 rows x 1 columns]
#                CreateDate           StartDate             EndDate  \
# 0     2025-10-23 12:26:00 2025-10-23 12:26:00 2025-10-23 13:26:00
# 1     2025-10-23 11:52:00 2025-10-23 11:52:00 2025-10-23 12:52:00
# 2     2025-10-23 10:53:00 2025-10-23 10:53:00 2025-10-23 11:53:00
